# %%
from os import environ
from pathlib import Path

import rtoml
import os
import pprint

# Get the list of user's
# environment variables
env_var = os.environ

# Print the list of user's
# environment variables
print("User's Environment variable:")
pprint.pprint(dict(env_var), width = 1)
# Out:
# User's Environment variable:
# {'ALLUSERSPROFILE': 'C:\\ProgramData',
#  'APPDATA': 'C:\\Users\\tin0976\\AppData\\Roaming',
#  'CLICOLOR': '1',
#  'COMMONPROGRAMFILES': 'C:\\Program '
#                        'Files\\Common '
#                        'Files',
#  'COMMONPROGRAMFILES(X86)': 'C:\\Program '
#                             'Files '
#                             '(x86)\\Common '
#                             'Files',
#  'COMMONPROGRAMW6432': 'C:\\Program '
#                        'Files\\Common '
#                        'Files',
#  'COMPUTERNAME': 'INBLRWGLS6Z33',
#  'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe',
#  'CONDA_PREFIX': 'C:\\Users\\tin0976\\Anaconda3',
#  'CSTB_INSTALLDIR': 'C:\\Program '
#                     'Files\\CyberSafe\\',
#  'CSTB_INSTALLDIR32': 'C:\\Program '
#                       'Files '
#                       '(x86)\\CyberSafe',
#  'CSTB_INSTALLDIR64': 'C:\\Program '
#                       'Files\\CyberSafe\\',
#  'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData',
#  'GIT_INSTALL_ROOT': 'C:\\Users\\tin0976\\scoop\\apps\\git\\current',
#  'GIT_PAGER': 'cat',
#  'HOMEDRIVE': 'H:',
#  'HOMEPATH': '\\',
#  'HOMESHARE': '\\\\VCN.DS.VOLVO.NET\\CLI-HM\\HM0813\\TIN0976',
#  'IPY_INTERRUPT_EVENT': '5096',
#  'IWBPATH': 'C:\\Program '
#             'Files '
#             '(x86)\\SAP\\FrontEnd\\iwb',
#  'JPY_INTERRUPT_EVENT': '5096',
#  'JPY_PARENT_PID': '2632',
#  'LOCALAPPDATA': 'C:\\Users\\tin0976\\AppData\\Local',
#  'LOGONSERVER': '\\\\JPSAITN273',
#  'MPLBACKEND': 'module://matplotlib_inline.backend_inline',
#  'NEXTHINK': 'C:\\Program '
#              'Files\\Nexthink\\Collector',
#  'NUMBER_OF_PROCESSORS': '8',
#  'ONEDRIVE': 'C:\\Users\\tin0976\\OneDrive '
#              '- '
#              'Volvo '
#              'Group',
#  'ONEDRIVECOMMERCIAL': 'C:\\Users\\tin0976\\OneDrive '
#                        '- '
#                        'Volvo '
#                        'Group',
#  'OS': 'Windows_NT',
#  'PAGER': 'cat',
#  'PATH': 'C:\\Users\\tin0976\\Anaconda3;C:\\Users\\tin0976\\Anaconda3\\Library\\mingw-w64\\bin;C:\\Users\\tin0976\\Anaconda3\\Library\\usr\\bin;C:\\Users\\tin0976\\Anaconda3\\Library\\bin;C:\\Users\\tin0976\\Anaconda3\\Scripts;C:\\Program '
#          'Files\\CyberSafe\\bin;C:\\Program '
#          'Files '
#          '(x86)\\CyberSafe\\bin;C:\\WINDOWS\\system32;C:\\WINDOWS;C:\\WINDOWS\\System32\\Wbem;C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0\\;C:\\WINDOWS\\System32\\OpenSSH\\;C:\\Program '
#          'Files '
#          '(x86)\\Micro '
#          'Focus\\RUMBA\\;C:\\Program '
#          'Files '
#          '(x86)\\Micro '
#          'Focus\\RUMBA\\System;C:\\Program '
#          'Files\\Microsoft '
#          'SQL '
#          'Server\\120\\DTS\\Binn\\;C:\\Program '
#          'Files\\Microsoft '
#          'SQL '
#          'Server\\Client '
#          'SDK\\ODBC\\110\\Tools\\Binn\\;C:\\Program '
#          'Files '
#          '(x86)\\Microsoft '
#          'SQL '
#          'Server\\120\\Tools\\Binn\\;C:\\Program '
#          'Files\\Microsoft '
#          'SQL '
#          'Server\\120\\Tools\\Binn\\;C:\\Program '
#          'Files '
#          '(x86)\\Microsoft '
#          'SQL '
#          'Server\\120\\Tools\\Binn\\ManagementStudio\\;C:\\Program '
#          'Files '
#          '(x86)\\Microsoft '
#          'SQL '
#          'Server\\120\\DTS\\Binn\\;C:\\Program '
#          'Files\\Calibre2\\;C:\\Program '
#          'Files\\nodejs\\;C:\\Users\\tin0976\\scoop\\shims;C:\\Users\\tin0976\\AppData\\Local\\Microsoft\\WindowsApps;C:\\Users\\tin0976\\AppData\\Local\\GitHubDesktop\\bin;C:\\Users\\tin0976\\AppData\\Roaming\\npm',
#  'PATHEXT': '.COM;.EXE;.BAT;.CMD;.VBS;.VBE;.JS;.JSE;.WSF;.WSH;.MSC',
#  'PROCESSOR_ARCHITECTURE': 'AMD64',
#  'PROCESSOR_IDENTIFIER': 'Intel64 '
#                          'Family '
#                          '6 '
#                          'Model '
#                          '140 '
#                          'Stepping '
#                          '1, '
#                          'GenuineIntel',
#  'PROCESSOR_LEVEL': '6',
#  'PROCESSOR_REVISION': '8c01',
#  'PROGRAMDATA': 'C:\\ProgramData',
#  'PROGRAMFILES': 'C:\\Program '
#                  'Files',
#  'PROGRAMFILES(X86)': 'C:\\Program '
#                       'Files '
#                       '(x86)',
#  'PROGRAMW6432': 'C:\\Program '
#                  'Files',
#  'PSMODULEPATH': 'C:\\Program '
#                  'Files\\WindowsPowerShell\\Modules;C:\\WINDOWS\\system32\\WindowsPowerShell\\v1.0\\Modules;C:\\Program '
#                  'Files '
#                  '(x86)\\Microsoft '
#                  'SQL '
#                  'Server\\120\\Tools\\PowerShell\\Modules\\;C:\\Program '
#                  'Files '
#                  '(x86)\\Microsoft '
#                  'Azure '
#                  'Information '
#                  'Protection\\Powershell',
#  'PUBLIC': 'C:\\Users\\Public',
#  'PYDEVD_USE_FRAME_EVAL': 'NO',
#  'SESSIONNAME': 'Console',
#  'SNC_LIB': 'C:\\Program '
#             'Files '
#             '(x86)\\CyberSafe\\bin\\sncgss32.dll',
#  'SNC_LIB_2': 'C:\\Program '
#               'Files '
#               '(x86)\\CyberSafe\\bin\\sncgss32.dll',
#  'SNC_LIB_64': 'C:\\Program '
#                'Files\\CyberSafe\\bin\\sncgss64.dll',
#  'SNC_LIB_64_2': 'C:\\Program '
#                  'Files\\CyberSafe\\bin\\sncgss64.dll',
#  'SYSTEMDRIVE': 'C:',
#  'SYSTEMROOT': 'C:\\WINDOWS',
#  'TEMP': 'C:\\Users\\tin0976\\AppData\\Local\\Temp',
#  'TERM': 'xterm-color',
#  'TMP': 'C:\\Users\\tin0976\\AppData\\Local\\Temp',
#  'UATDATA': 'C:\\WINDOWS\\CCM\\UATData\\D9F8C395-CAB8-491d-B8AC-179A1FE1BE77',
#  'USERDNSDOMAIN': 'vcn.ds.volvo.net',
#  'USERDOMAIN': 'VCN',
#  'USERDOMAIN_ROAMINGPROFILE': 'VCN',
#  'USERNAME': 'tin0976',
#  'USERPROFILE': 'C:\\Users\\tin0976',
#  'WINDIR': 'C:\\WINDOWS',
#  'WPDFDOMAIN': 'VCN.DS.VOLVO.NET',
#  'WPDFSCOPE': 'Prod',
#  'ZES_ENABLE_SYSMAN': '1',
#  '__PSLOCKDOWNPOLICY': '0'}

# %%
Path(environ["VAULT"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 Path(environ["VAULT"])
#
# File ~\Anaconda3\lib\os.py:679, in _Environ.__getitem__(self, key)
#     676     value = self._data[self.encodekey(key)]
#     677 except KeyError:
#     678     # raise KeyError with the original key value
# --> 679     raise KeyError(key) from None
#     680 return self.decodevalue(value)
#
# KeyError: 'VAULT'

# %%
Path()

# %%
pip install rtoml
